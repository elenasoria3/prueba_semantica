# %% [markdown]
# <a href="https://colab.research.google.com/github/elenasoria3/prueba_semantica/blob/main/SpaCy_informationextraction_elenasorialopez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extraer conocimiento del texto: Extracción de información con spaCy y Neo4j
# https://towardsdatascience.com/extract-knowledge-from-text-end-to-end-information-extraction-pipeline-with-spacy-and-neo4j-502b2b1e0754

# %%
# !pip install crosslingual-coreference==0.2.3 spacy-transformers==1.1.5 wikipedia neo4j
# !pip install --upgrade google-cloud-storage
# !pip install transformers==4.18.0
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: crosslingual-coreference==0.2.3 in /usr/local/lib/python3.8/dist-packages (0.2.3)
# Requirement already satisfied: spacy-transformers==1.1.5 in /usr/local/lib/python3.8/dist-packages (1.1.5)
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.8/dist-packages (1.4.0)
# Requirement already satisfied: neo4j in /usr/local/lib/python3.8/dist-packages (5.2.1)
# Requirement already satisfied: torchvision<0.12.0 in /usr/local/lib/python3.8/dist-packages (from crosslingual-coreference==0.2.3) (0.11.3)
# Requirement already satisfied: spacy<4.0,>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from crosslingual-coreference==0.2.3) (3.3.1)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.8/dist-packages (from crosslingual-coreference==0.2.3) (7.1.2)
# Requirement already satisfied: allennlp<3.0,>=2.8 in /usr/local/lib/python3.8/dist-packages (from crosslingual-coreference==0.2.3) (2.10.1)
# Requirement already satisfied: torch<1.11.0,>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from crosslingual-coreference==0.2.3) (1.10.2)
# Requirement already satisfied: allennlp-models<3.0,>=2.8 in /usr/local/lib/python3.8/dist-packages (from crosslingual-coreference==0.2.3) (2.10.1)
# Requirement already satisfied: torchaudio<0.11 in /usr/local/lib/python3.8/dist-packages (from crosslingual-coreference==0.2.3) (0.10.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers==1.1.5) (2.4.5)
# Collecting transformers<4.18.0,>=3.4.0
#   Using cached transformers-4.17.0-py3-none-any.whl (3.8 MB)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers==1.1.5) (0.8.6)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (3.7)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.1.0)
# Requirement already satisfied: h5py>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (3.7.0)
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (4.64.1)
# Requirement already satisfied: numpy>=1.21.4 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.21.6)
# Requirement already satisfied: jsonnet>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.19.1)
# Requirement already satisfied: wandb<0.13.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.12.21)
# Requirement already satisfied: cached-path<1.2.0,>=1.1.3 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.1.6)
# Requirement already satisfied: more-itertools>=8.12.0 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (9.0.0)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.7.3)
# Requirement already satisfied: base58>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.1.1)
# Requirement already satisfied: pytest>=6.2.5 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (7.2.0)
# Requirement already satisfied: lmdb>=1.2.1 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.4.0)
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.4.2)
# Requirement already satisfied: tensorboardX>=1.2 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.5.1)
# Requirement already satisfied: fairscale==0.4.6 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.4.6)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.28.1)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.3.6)
# Requirement already satisfied: sentencepiece>=0.1.96 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.1.97)
# Requirement already satisfied: traitlets>5.1.1 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (5.6.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (3.19.6)
# Requirement already satisfied: filelock<3.8,>=3.3 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (3.7.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.0.53)
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.0.2)
# Requirement already satisfied: huggingface-hub>=0.0.16 in /usr/local/lib/python3.8/dist-packages (from allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.10.1)
# Requirement already satisfied: conllu==4.4.2 in /usr/local/lib/python3.8/dist-packages (from allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (4.4.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.8/dist-packages (from allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.7.1)
# Requirement already satisfied: py-rouge==1.1 in /usr/local/lib/python3.8/dist-packages (from allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.1)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.8/dist-packages (from allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (6.1.1)
# Requirement already satisfied: word2number>=1.1 in /usr/local/lib/python3.8/dist-packages (from allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.1)
# Requirement already satisfied: boto3<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.26.27)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.7.0)
# Requirement already satisfied: rich<13.0,>=12.1 in /usr/local/lib/python3.8/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (12.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.6.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.27 in /usr/local/lib/python3.8/dist-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.29.27)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore<1.30.0,>=1.29.27->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.8/dist-packages (from botocore<1.30.0,>=1.29.27->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.26.13)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.8.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.3.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.15.0)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.57.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.15.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (5.2.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.8/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.0.16->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.0.16->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.0.16->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (4.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.6.5->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.6.5->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2022.6.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.0.16->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.4.8)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.5->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (22.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.5->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.5->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.0.4)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.5->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.5->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.1.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.6.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.1->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (3.1.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (8.0.17)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (1.8.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (3.0.10)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (2.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (0.10.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (3.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (57.4.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (0.7.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (1.0.3)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (5.2.1)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision<0.12.0->crosslingual-coreference==0.2.3) (7.1.2)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers==1.1.5) (0.12.1)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.11.1)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.0.11)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.4.0)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (5.4.8)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.3.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (2.3)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (3.1.29)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp<3.0,>=2.8->crosslingual-coreference==0.2.3) (5.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from neo4j) (2022.6)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.70.14)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (3.8.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.3.5)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (2022.11.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (3.1.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.18.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (9.0.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (6.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (1.3.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from ftfy->allennlp-models<3.0,>=2.8->crosslingual-coreference==0.2.3) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<4.0,>=3.1.0->crosslingual-coreference==0.2.3) (2.0.1)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.18.0
#     Uninstalling transformers-4.18.0:
#       Successfully uninstalled transformers-4.18.0
# Successfully installed transformers-4.17.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.8/dist-packages (2.7.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage) (2.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage) (2.8.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage) (2.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.57.0)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.15.0 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (3.19.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (1.15.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.2.8)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.8/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage) (1.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.18.0
#   Using cached transformers-4.18.0-py3-none-any.whl (4.0 MB)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (0.12.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (3.7.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (2022.6.2)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (0.0.53)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (1.21.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (0.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers==4.18.0) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.18.0) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers==4.18.0) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.18.0) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.18.0) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.18.0) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.18.0) (2.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==4.18.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==4.18.0) (1.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==4.18.0) (1.15.0)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.17.0
#     Uninstalling transformers-4.17.0:
#       Successfully uninstalled transformers-4.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy-transformers 1.1.5 requires transformers<4.18.0,>=3.4.0, but you have transformers 4.18.0 which is incompatible.
# Successfully installed transformers-4.18.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 4.5 MB/s
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.3.0) (3.3.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.17)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.10.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (57.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.10.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.64.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
import crosslingual_coreference
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
# https://github.com/Babelscape/rebel/blob/main/spacy_component.py
import requests
import re
import hashlib
from spacy import Language
from typing import List

from spacy.tokens import Doc, Span

from transformers import pipeline

def call_wiki_api(item):
  try:
    url = f"https://www.wikidata.org/w/api.php?action=wbsearchentities&search={item}&language=en&format=json"
    data = requests.get(url).json()
    # Return the first id (Could upgrade this in the future)
    return data['search'][0]['id']
  except:
    return 'id-less'

def extract_triplets(text):
    """
    Function to parse the generated text and extract the triplets
    """
    triplets = []
    relation, subject, relation, object_ = '', '', '', ''
    text = text.strip()
    current = 'x'
    for token in text.replace("<s>", "").replace("<pad>", "").replace("</s>", "").split():
        if token == "<triplet>":
            current = 't'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
                relation = ''
            subject = ''
        elif token == "<subj>":
            current = 's'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
            object_ = ''
        elif token == "<obj>":
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and relation != '' and object_ != '':
        triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})

    return triplets


@Language.factory(
    "rebel",
    requires=["doc.sents"],
    assigns=["doc._.rel"],
    default_config={
        "model_name": "Babelscape/rebel-large",
        "device": 0,
    },
)
class RebelComponent:
    def __init__(
        self,
        nlp,
        name,
        model_name: str,
        device: int,
    ):
        assert model_name is not None, ""
        self.triplet_extractor = pipeline("text2text-generation", model=model_name, tokenizer=model_name, device=device)
        self.entity_mapping = {}
        # Register custom extension on the Doc
        if not Doc.has_extension("rel"):
          Doc.set_extension("rel", default={})

    def get_wiki_id(self, item: str):
        mapping = self.entity_mapping.get(item)
        if mapping:
          return mapping
        else:
          res = call_wiki_api(item)
          self.entity_mapping[item] = res
          return res

    
    def _generate_triplets(self, sent: Span) -> List[dict]:
          output_ids = self.triplet_extractor(sent.text, return_tensors=True, return_text=False)[0]["generated_token_ids"]["output_ids"]
          extracted_text = self.triplet_extractor.tokenizer.batch_decode(output_ids[0])
          extracted_triplets = extract_triplets(extracted_text[0])
          return extracted_triplets

    def set_annotations(self, doc: Doc, triplets: List[dict]):
        for triplet in triplets:

            # Remove self-loops (relationships that start and end at the entity)
            if triplet['head'] == triplet['tail']:
                continue

            # Use regex to search for entities
            head_span = re.search(triplet["head"], doc.text)
            tail_span = re.search(triplet["tail"], doc.text)

            # Skip the relation if both head and tail entities are not present in the text
            # Sometimes the Rebel model hallucinates some entities
            if not head_span or not tail_span:
              continue

            index = hashlib.sha1("".join([triplet['head'], triplet['tail'], triplet['type']]).encode('utf-8')).hexdigest()
            if index not in doc._.rel:
                # Get wiki ids and store results
                doc._.rel[index] = {"relation": triplet["type"], "head_span": {'text': triplet['head'], 'id': self.get_wiki_id(triplet['head'])}, "tail_span": {'text': triplet['tail'], 'id': self.get_wiki_id(triplet['tail'])}}

    def __call__(self, doc: Doc) -> Doc:
        for sent in doc.sents:
            sentence_triplets = self._generate_triplets(sent)
            self.set_annotations(doc, sentence_triplets)
        return doc

# %%
DEVICE = -1 # Number of the GPU, -1 if want to use CPU

# Add coreference resolution model
coref = spacy.load('en_core_web_sm', disable=['ner', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer'])
coref.add_pipe(
    "xx_coref", config={"chunk_size": 2500, "chunk_overlap": 2, "device": DEVICE})

# Define rel extraction model

rel_ext = spacy.load('en_core_web_sm', disable=['ner', 'lemmatizer', 'attribute_rules', 'tagger'])
rel_ext.add_pipe("rebel", config={
    'device':DEVICE, # Number of the GPU, -1 if want to use CPU
    'model_name':'Babelscape/rebel-large'} # Model used, will default to 'Babelscape/rebel-large' if not given
    )
# Out:
# models/crosslingual-coreference/minilm/model.tar.gz: 358490KB [00:11, 31132.62KB/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Downloading:   0%|          | 0.00/357 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/489 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/225M [00:00<?, ?B/s]
# Some weights of the model checkpoint at nreimers/mMiniLMv2-L12-H384-distilled-from-XLMR-Large were not used when initializing XLMRobertaModel: ['lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias']
# - This IS expected if you are initializing XLMRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaModel were not initialized from the model checkpoint at nreimers/mMiniLMv2-L12-H384-distilled-from-XLMR-Large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.8/dist-packages/allennlp/models/archival.py:325: UserWarning: The model models/crosslingual-coreference/minilm/model.tar.gz was trained on a newer version of AllenNLP (v2.9.3), but you're using version 2.10.1.
#   warnings.warn(
# Downloading:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/123 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/344 [00:00<?, ?B/s]

# %% [markdown]
# # Input Text 1: Stranger Things

# %%
input_text = """Stranger Things is an American science fiction horror drama television series created by the Duffer Brothers, who also serve as showrunners and are executive producers along with Shawn Levy and Dan Cohen. Produced by Monkey Massacre Productions and Levy's 21 Laps Entertainment, the first season was released on Netflix on July 15, 2016. Its second, third, and fourth seasons followed in October 2017, July 2019, and May and July 2022, respectively. In February 2022, the series was renewed for a fifth and final season. Set in the 1980s, primarily in the fictional town of Hawkins, Indiana, the series centers on a number of mysteries and supernatural events occurring around the town and their impact on an ensemble of child and adult characters. It stars Winona Ryder, David Harbour, Finn Wolfhard, Millie Bobby Brown, Gaten Matarazzo, Caleb McLaughlin, Natalia Dyer, Charlie Heaton, Cara Buono, Matthew Modine, Noah Schnapp, Sadie Sink, Joe Keery, Dacre Montgomery, Sean Astin, Paul Reiser, Maya Hawke, Priah Ferguson, and Brett Gelman."""

coref_text = coref(input_text)._.resolved_text

doc = rel_ext(coref_text)

for value, rel_dict in doc._.rel.items():
    print(f"{value}: {rel_dict}")
# Out:
# 929c1947865c4a6f98cf5d264f7d8ee9145cdf00: {'relation': 'genre', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'science fiction', 'id': 'Q24925'}}
# a89f7a968c75099ddb2a61b3b6316d0ca4b6b57d: {'relation': 'genre', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'horror drama', 'id': 'Q103319035'}}
# 05a542e242584bf1bc38a6f0ea8f22d45cec3ffc: {'relation': 'creator', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Duffer Brothers', 'id': 'Q26097618'}}
# 8b1073b6489aa9f945497157ee3ef014e93d7410: {'relation': 'creator', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Shawn Levy', 'id': 'Q323076'}}
# cd572439dec552b13b64328c1fe7fda3312fbd45: {'relation': 'creator', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Dan Cohen', 'id': 'Q22108672'}}
# 65f829f9ead93ee377663ba41e427fd371e32e1b: {'relation': 'notable work', 'head_span': {'text': 'Duffer Brothers', 'id': 'Q26097618'}, 'tail_span': {'text': 'Stranger Things', 'id': 'Q19798734'}}
# 9d568acf78f05e7066ef9f3390de8fd96a010de8: {'relation': 'occupation', 'head_span': {'text': 'Duffer Brothers', 'id': 'Q26097618'}, 'tail_span': {'text': 'showrunner', 'id': 'Q1440873'}}
# e95c9325a52d34426dbefa4de7dd58405f085f69: {'relation': 'occupation', 'head_span': {'text': 'Duffer Brothers', 'id': 'Q26097618'}, 'tail_span': {'text': 'executive producer', 'id': 'Q1053574'}}
# 680dc4c5bea05425ea30f625e6312656225d85c6: {'relation': 'notable work', 'head_span': {'text': 'Shawn Levy', 'id': 'Q323076'}, 'tail_span': {'text': 'Stranger Things', 'id': 'Q19798734'}}
# 18188427fa4a4ff685012f108a27a791546fcdff: {'relation': 'occupation', 'head_span': {'text': 'Shawn Levy', 'id': 'Q323076'}, 'tail_span': {'text': 'showrunner', 'id': 'Q1440873'}}
# 5df452a0435f98bd1fe93c0281c70e849e3d91d7: {'relation': 'occupation', 'head_span': {'text': 'Shawn Levy', 'id': 'Q323076'}, 'tail_span': {'text': 'executive producer', 'id': 'Q1053574'}}
# 07e9d499e93e879085fb5a8089ab9743b8134086: {'relation': 'notable work', 'head_span': {'text': 'Dan Cohen', 'id': 'Q22108672'}, 'tail_span': {'text': 'Stranger Things', 'id': 'Q19798734'}}
# 4c8dbb2d04c96b29938250bab47c98473a993fed: {'relation': 'occupation', 'head_span': {'text': 'Dan Cohen', 'id': 'Q22108672'}, 'tail_span': {'text': 'showrunner', 'id': 'Q1440873'}}
# 2c74db8344a3671dec2e078f29b04697d5a07f0a: {'relation': 'occupation', 'head_span': {'text': 'Dan Cohen', 'id': 'Q22108672'}, 'tail_span': {'text': 'executive producer', 'id': 'Q1053574'}}
# 5f50867bd622dea8d11b42190ab4d5b1053214bd: {'relation': 'founded by', 'head_span': {'text': '21 Laps Entertainment', 'id': 'Q16973462'}, 'tail_span': {'text': 'Shawn Levy', 'id': 'Q323076'}}
# c2b6d20a177f440411d296afcbdf878cea639508: {'relation': 'has part', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'second', 'id': 'Q11574'}}
# c2bc21bade490447d2f983a765d2f18db5ea78f8: {'relation': 'has part', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'third', 'id': 'Q224074'}}
# 20a2d473c78231ef724ae8dd783e3f001fc44679: {'relation': 'has part', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'fourth', 'id': 'Q267984'}}
# 9aad7995940f1ae98f8a1f11f269cd3daace3be9: {'relation': 'part of the series', 'head_span': {'text': 'second', 'id': 'Q11574'}, 'tail_span': {'text': 'Stranger Things', 'id': 'Q19798734'}}
# 023d86d4a90188f85eafd5bb3056efc90a83f610: {'relation': 'part of the series', 'head_span': {'text': 'third', 'id': 'Q224074'}, 'tail_span': {'text': 'Stranger Things', 'id': 'Q19798734'}}
# cf9034db9b9b607809c88d066b799d5b5a4393f7: {'relation': 'part of the series', 'head_span': {'text': 'fourth', 'id': 'Q267984'}, 'tail_span': {'text': 'Stranger Things', 'id': 'Q19798734'}}
# e3c718430ef4e9e295e973ee0066048255de889e: {'relation': 'has part', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'fifth and final season', 'id': 'id-less'}}
# 4d7520aeaf35c31a03123b5f4ad8abd2277ef847: {'relation': 'part of the series', 'head_span': {'text': 'fifth and final season', 'id': 'id-less'}, 'tail_span': {'text': 'Stranger Things', 'id': 'Q19798734'}}
# 76969a34e57587875262df3d81d0eb9423eacc29: {'relation': 'narrative location', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Hawkins, Indiana', 'id': 'Q51368863'}}
# 26a1aeb9ddbbf4a74f99c6f258dd7b1594e393bb: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Winona Ryder', 'id': 'Q101797'}}
# 64d3abe121418448bed3fbaca63dadd961c81da5: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'David Harbour', 'id': 'Q391359'}}
# a175dd11b071b6731d1f87413dc6a66422c2328f: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Finn Wolfhard', 'id': 'Q26308335'}}
# fbcd3dd109b29b80485775ddf4d94156481ac36f: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Millie Bobby Brown', 'id': 'Q25936414'}}
# 6b9984e407458d756c32019dc99c3a6426751f22: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Gaten Matarazzo', 'id': 'Q26704332'}}
# 171be1b8b1909c8f3a3ad7bc4d6d3f23e5aa4d0a: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Caleb McLaughlin', 'id': 'Q26926382'}}
# a77bc08ba78fb2511a7744ae1790dbfa26b06619: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Natalia Dyer', 'id': 'Q26232134'}}
# e8177beaeb54b079757abb2f1f2e03be610983ee: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Charlie Heaton', 'id': 'Q20974088'}}
# 81b7629e483b1f148c08c253254c90f4231b90b5: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Cara Buono', 'id': 'Q289540'}}
# f625a753db1ed721baab4633d25b2af01cbaa891: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Matthew Modine', 'id': 'Q318249'}}
# eb5cd6156cb4596c9a2660e7e1edc0cd3ff0f25f: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Noah Schnapp', 'id': 'Q26926633'}}
# 85792b3d7db745fd8fa6936e93883263999945c2: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Sadie Sink', 'id': 'Q27452406'}}
# b2f95ae795e282bece99b8c2edb54e1faec98acf: {'relation': 'cast member', 'head_span': {'text': 'Stranger Things', 'id': 'Q19798734'}, 'tail_span': {'text': 'Joe Keery', 'id': 'Q27064031'}}

# %%
import pandas as pd
import wikipedia
from neo4j import GraphDatabase

# Estas tres variables deben cambiar a la sesión del proyecto de Neo4J creada por cada uno
host = 'bolt://44.192.106.246:7687'
user = 'neo4j'
password = 'hairpin-tolerance-blows'
driver = GraphDatabase.driver(host,auth=(user, password))

import_query = """
UNWIND $data AS row
MERGE (h:Entity {id: CASE WHEN NOT row.head_span.id = 'id-less' THEN row.head_span.id ELSE row.head_span.text END})
ON CREATE SET h.text = row.head_span.text
MERGE (t:Entity {id: CASE WHEN NOT row.tail_span.id = 'id-less' THEN row.tail_span.id ELSE row.tail_span.text END})
ON CREATE SET t.text = row.tail_span.text
WITH row, h, t
CALL apoc.merge.relationship(h, toUpper(replace(row.relation,' ', '_')),
  {},
  {},
  t,
  {}
)
YIELD rel
RETURN distinct 'done' AS result;
"""


def run_query(query, params={}):
    with driver.session() as session:
        result = session.run(query, params)
        return pd.DataFrame([r.values() for r in result], columns=result.keys())

def store_wikipedia_summary(page):
  try:
    input_text = wikipedia.page(page).summary
    coref_text = coref(input_text)._.resolved_text
    doc = rel_ext(coref_text)
    params = [rel_dict for value, rel_dict in doc._.rel.items()]
    run_query(import_query, {'data': params})
  except Exception as e:
    print(f"Couldn't parse text for {page} due to {e}")

# %% [markdown]
# # Input Text 2: Eleven

# %%
input_text2 = """Eleven is the daughter of Teresa "Terry" Ives, and a participant in the Project MKUltra experiments conducted by the Central Intelligence Agency (CIA). Eleven appears to have been born a psychic with notable telekinetic and extrasensory abilities. However, when she uses these abilities to a significant degree, she becomes temporarily weakened and her nose bleeds. At birth, Eleven was taken away from her mother by Dr. Martin Brenner and was raised as a test subject in Hawkins National Laboratory in order to develop her psychokinetic skills. When placed in a sensory deprivation tank, she can use remote viewing to access other dimensions, primarily for the purposes of espionage. In addition, Eleven can open and close portals, known as “Gates”, to a parallel dimension called the Upside Down."""

coref_text2 = coref(input_text2)._.resolved_text

doc2 = rel_ext(coref_text2)

for value, rel_dict in doc2._.rel.items():
    print(f"{value}: {rel_dict}")
# Out:
# dd58a2547cf6ed6073332e24a8857765fdfa372e: {'relation': 'operator', 'head_span': {'text': 'Project MKUltra', 'id': 'Q815614'}, 'tail_span': {'text': 'Central Intelligence Agency', 'id': 'Q37230'}}
# 61d967bf042060a06b19fd96c1b3e59b1b3aa4cb: {'relation': 'subclass of', 'head_span': {'text': 'extrasensory', 'id': 'Q26157035'}, 'tail_span': {'text': 'psychic', 'id': 'Q2917466'}}
# c0a9251752b818e8c42518b8d582692b24fb2010: {'relation': 'subclass of', 'head_span': {'text': 'telekinetic', 'id': 'Q186446'}, 'tail_span': {'text': 'extrasensory abilities', 'id': 'id-less'}}
# 6b4e10322f2ec5b0f52abd3646255fa375f5790b: {'relation': 'residence', 'head_span': {'text': 'Eleven', 'id': 'Q37136'}, 'tail_span': {'text': 'Hawkins National Laboratory', 'id': 'id-less'}}
# 76c2628019b7e18255d76dccb3bc7f1b96b2ccc2: {'relation': 'use', 'head_span': {'text': 'remote viewing', 'id': 'Q844197'}, 'tail_span': {'text': 'espionage', 'id': 'Q165950'}}
# f03f9e26ef417ff62de7b3fe8a91ea56dfb97ae5: {'relation': 'instance of', 'head_span': {'text': 'Upside Down', 'id': 'Q769527'}, 'tail_span': {'text': 'parallel dimension', 'id': 'Q3895172'}}

# %%
params = [rel_dict for value, rel_dict in doc2._.rel.items()]
run_query(import_query, {'data': params})
# Out:
#   result
# 0   done

# %% [markdown]
# # Input Text 3: Cast Members and Characters

# %%
input_text3 = """Winona Ryder as Joyce Byers,the mother of Will and Jonathan Byers. She is divorced from Lonnie Byers, the father of Will and Jonathan. In season two, she dates her old high school classmate, Bob, until his death later in the season. She and Hopper have feelings for each other.
David Harbour as Jim Hopper,chief of Hawkins Police Department. After his young daughter Sara died of cancer, Hopper divorced and lapsed into alcoholism. Eventually he grows to be more responsible, saving Will Byers after he is taken in season 1, as well as taking Eleven as his adopted daughter. He and Joyce have feelings for each other.
Finn Wolfhard as Mike Wheeler,middle child of Karen and Ted Wheeler, brother of Nancy and Holly, and one of three friends of Will Byers. He is an intelligent and conscientious student and is committed to his friends. He develops romantic feelings for Eleven and later dates her.
Millie Bobby Brown as Eleven / Jane Hopper, a teen girl with telepathic and psychokinetic abilities, a result of being one of Dr. Brenner's subjects from Hawkins National Laboratory. She escapes the lab and eventually becomes an adoptive daughter to Jim Hopper taking his surname, and adjusts to living a normal life with the help of Mike (whom she later dates) and his friends.
Gaten Matarazzo as Dustin Henderson,one of Will Byers' friends. His cleidocranial dysplasia causes him to lisp. In the second season, he is proud of his new front teeth and is attracted to Max. In season 3, he gets a girlfriend, Suzie (portrayed by Gabriella Pizzolo), whom he met at Camp Know Where prior to the start of the season.
Caleb McLaughlin as Lucas Sinclair,one of Will's friends. He is wary of Eleven but later befriends her. In season two, he is one of Max's love interests and eventually becomes her boyfriend in season three. He becomes more popular in season 4 as a result of joining the Hawkins High basketball team, which briefly puts him at odds with his regular friend group.
Natalia Dyer as Nancy Wheeler,daughter of Karen and Ted and older sister of Mike and Holly. Studious and rule-abiding, Nancy finds another side of herself while investigating the Hawkins Lab and the death of her friend Barbara. In the first two seasons, she is the girlfriend of Steve Harrington but breaks up with him and then dates Jonathan Byers. She is an aspiring journalist.
Charlie Heaton as Jonathan Byers,the older brother of Will Byers and the son of Joyce Byers. He is a quiet and kind-hearted teenager, an outsider at school, and an aspiring photographer. He is close with his mother and brother, and he becomes the boyfriend of Nancy Wheeler.
Cara Buono as Karen Wheeler,  mother of Nancy, Mike, and toddler Holly. Karen has a brief fling with Billy in season 3."""

coref_text3 = coref(input_text3)._.resolved_text

doc3 = rel_ext(coref_text3)

for value, rel_dict in doc3._.rel.items():
    print(f"{value}: {rel_dict}")
# Out:
# /usr/local/lib/python3.8/dist-packages/allennlp/modules/token_embedders/pretrained_transformer_embedder.py:385: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   num_effective_segments = (seq_lengths + self._max_length - 1) // self._max_length
# 950a8e2b5bdda9e10c5679da4b0d687953b33bb6: {'relation': 'performer', 'head_span': {'text': 'Will', 'id': 'Q155656'}, 'tail_span': {'text': 'Winona Ryder', 'id': 'Q101797'}}
# f18829d1d96012e9025e807d69df0462c3f944bc: {'relation': 'sibling', 'head_span': {'text': 'Will', 'id': 'Q155656'}, 'tail_span': {'text': 'Jonathan Byers', 'id': 'Q65515725'}}
# f30b5503711c782084bfd0c6c0288353a8017583: {'relation': 'performer', 'head_span': {'text': 'Jonathan Byers', 'id': 'Q65515725'}, 'tail_span': {'text': 'Winona Ryder', 'id': 'Q101797'}}
# fa560bfa311b82ee6b49c66ed3b3957b66054578: {'relation': 'sibling', 'head_span': {'text': 'Jonathan Byers', 'id': 'Q65515725'}, 'tail_span': {'text': 'Will', 'id': 'Q155656'}}
# 7dcd7e45b34a126f49f0a0975d696a856383d89b: {'relation': 'mother', 'head_span': {'text': 'Will', 'id': 'Q155656'}, 'tail_span': {'text': 'Joyce Byers', 'id': 'Q65515261'}}
# fd2d08ff33b544f618f6ed0982ce6de62856973e: {'relation': 'mother', 'head_span': {'text': 'Jonathan Byers', 'id': 'Q65515725'}, 'tail_span': {'text': 'Joyce Byers', 'id': 'Q65515261'}}
# ebd956134063081a746a1d52d1bdd03312bee7ef: {'relation': 'performer', 'head_span': {'text': 'Jim Hopper', 'id': 'Q65515536'}, 'tail_span': {'text': 'David Harbour', 'id': 'Q391359'}}
# 64d94f1e67d6ce126908697f65934a3c26a296bd: {'relation': 'occupation', 'head_span': {'text': 'Jim Hopper', 'id': 'Q65515536'}, 'tail_span': {'text': 'alcoholism', 'id': 'Q15326'}}
# 0975c96b9cf50340ea8dbb34d23913f27a242f91: {'relation': 'child', 'head_span': {'text': 'Jim Hopper,chief of Hawkins Police Department', 'id': 'id-less'}, 'tail_span': {'text': 'Eleven', 'id': 'Q37136'}}
# b9dd489aa2e90e227cc57f44870d4822a3b23439: {'relation': 'father', 'head_span': {'text': 'Eleven', 'id': 'Q37136'}, 'tail_span': {'text': 'Jim Hopper,chief of Hawkins Police Department', 'id': 'id-less'}}
# 4a32946f3b9e3ea10e5a99f107302201d6436745: {'relation': 'performer', 'head_span': {'text': 'Mike Wheeler', 'id': 'Q65502940'}, 'tail_span': {'text': 'Finn Wolfhard', 'id': 'Q26308335'}}
# f7694f1e784e43b68cddec6bc3ae7f2331f9d4aa: {'relation': 'sibling', 'head_span': {'text': 'Mike Wheeler', 'id': 'Q65502940'}, 'tail_span': {'text': 'Nancy', 'id': 'Q40898'}}
# 53005b21368f886e8c3255bb94d8e3d3a6c00fbd: {'relation': 'sibling', 'head_span': {'text': 'Mike Wheeler', 'id': 'Q65502940'}, 'tail_span': {'text': 'Holly', 'id': 'Q117085'}}
# 8f9d9755b678edc2c484ea1951572aa56c8aaaf8: {'relation': 'sibling', 'head_span': {'text': 'Nancy', 'id': 'Q40898'}, 'tail_span': {'text': 'Mike Wheeler', 'id': 'Q65502940'}}
# b97ed659ace046012243c6d6dcb2242130dfe90d: {'relation': 'sibling', 'head_span': {'text': 'Nancy', 'id': 'Q40898'}, 'tail_span': {'text': 'Holly', 'id': 'Q117085'}}
# b8f353140bf7ed230f89abfc118b73e7f387774e: {'relation': 'sibling', 'head_span': {'text': 'Holly', 'id': 'Q117085'}, 'tail_span': {'text': 'Mike Wheeler', 'id': 'Q65502940'}}
# f42967631ec225718e21dbf5a14112edd496c1f3: {'relation': 'sibling', 'head_span': {'text': 'Holly', 'id': 'Q117085'}, 'tail_span': {'text': 'Nancy', 'id': 'Q40898'}}
# 2f3aeb1a8ebb45699d4cecfe9eb48821cf9d7423: {'relation': 'mother', 'head_span': {'text': 'Mike Wheeler', 'id': 'Q65502940'}, 'tail_span': {'text': 'Karen', 'id': 'Q1221747'}}
# c28a3227dfcc1f2a6794276876a3908f494cf818: {'relation': 'father', 'head_span': {'text': 'Mike Wheeler', 'id': 'Q65502940'}, 'tail_span': {'text': 'Ted Wheeler', 'id': 'Q7693864'}}
# 22f57bf474495c98f1cfd3b4dea4a95d907f5c27: {'relation': 'child', 'head_span': {'text': 'Karen', 'id': 'Q1221747'}, 'tail_span': {'text': 'Mike Wheeler', 'id': 'Q65502940'}}
# 5509f912981fc15d040082476d040a4f435173e0: {'relation': 'spouse', 'head_span': {'text': 'Karen', 'id': 'Q1221747'}, 'tail_span': {'text': 'Ted Wheeler', 'id': 'Q7693864'}}
# 13072d02d97ceca75f67d1f08b910652e56e3e1c: {'relation': 'child', 'head_span': {'text': 'Karen', 'id': 'Q1221747'}, 'tail_span': {'text': 'Nancy', 'id': 'Q40898'}}
# d50778140bcf165ed13d3e89322d8ac57fabfd7d: {'relation': 'child', 'head_span': {'text': 'Karen', 'id': 'Q1221747'}, 'tail_span': {'text': 'Holly', 'id': 'Q117085'}}
# a07cf636b952bcd2c25940e27495506673bc42b7: {'relation': 'child', 'head_span': {'text': 'Ted Wheeler', 'id': 'Q7693864'}, 'tail_span': {'text': 'Mike Wheeler', 'id': 'Q65502940'}}
# 2ce2e6a583543e2ff3c1fe5906418a29fbc69450: {'relation': 'spouse', 'head_span': {'text': 'Ted Wheeler', 'id': 'Q7693864'}, 'tail_span': {'text': 'Karen', 'id': 'Q1221747'}}
# d60ac0d3beaf2d43e3f1a062c0cc47b9e89a06ee: {'relation': 'child', 'head_span': {'text': 'Ted Wheeler', 'id': 'Q7693864'}, 'tail_span': {'text': 'Nancy', 'id': 'Q40898'}}
# 9af2e631baa5a673755d8771a8e8dbd5d43618f6: {'relation': 'child', 'head_span': {'text': 'Ted Wheeler', 'id': 'Q7693864'}, 'tail_span': {'text': 'Holly', 'id': 'Q117085'}}
# 5f4c276d72609b66ce6d35107dd7904b7478f408: {'relation': 'mother', 'head_span': {'text': 'Nancy', 'id': 'Q40898'}, 'tail_span': {'text': 'Karen', 'id': 'Q1221747'}}
# 90015568457b31c8cb0d8e118917093ec2c38946: {'relation': 'father', 'head_span': {'text': 'Nancy', 'id': 'Q40898'}, 'tail_span': {'text': 'Ted Wheeler', 'id': 'Q7693864'}}
# 90ce630be78b140ff25ce27c101232bd47795f3f: {'relation': 'performer', 'head_span': {'text': 'Eleven / Jane Hopper', 'id': 'id-less'}, 'tail_span': {'text': 'Millie Bobby Brown', 'id': 'Q25936414'}}
# 49618bd33a784bfe66416b2d58ca6ba2e1fb9066: {'relation': 'father', 'head_span': {'text': 'Eleven / Jane Hopper', 'id': 'id-less'}, 'tail_span': {'text': 'Jim Hopper', 'id': 'Q65515536'}}
# 8aec6e14c69c4c8568ac4420e5e3ee8cc7f248a5: {'relation': 'child', 'head_span': {'text': 'Jim Hopper', 'id': 'Q65515536'}, 'tail_span': {'text': 'Eleven / Jane Hopper', 'id': 'id-less'}}
# f54fd22ecc07ad5a90d9c56a2417234a6a536ba4: {'relation': 'performer', 'head_span': {'text': 'Dustin Henderson', 'id': 'Q65503952'}, 'tail_span': {'text': 'Gaten Matarazzo', 'id': 'Q26704332'}}
# db01fac9919dbe9af058fef01928c694f91dfabd: {'relation': 'medical condition treated', 'head_span': {'text': 'Gaten Matarazzo', 'id': 'Q26704332'}, 'tail_span': {'text': 'lisp', 'id': 'Q132874'}}
# 3ff69fd326f086ac71271f53f0a63974e35d4c15: {'relation': 'characters', 'head_span': {'text': 'second season', 'id': 'Q256235'}, 'tail_span': {'text': 'Gaten Matarazzo', 'id': 'Q26704332'}}
# 54eaec4a4e4d3fc2f3e185e502a12e85c7170e2f: {'relation': 'characters', 'head_span': {'text': 'second season', 'id': 'Q256235'}, 'tail_span': {'text': 'Max', 'id': 'Q16422172'}}
# 667589d75c24b6c9cb9bb9098050b85c519be693: {'relation': 'present in work', 'head_span': {'text': 'Gaten Matarazzo', 'id': 'Q26704332'}, 'tail_span': {'text': 'second season', 'id': 'Q256235'}}
# 9dbb6810ae35a31af55752f34645be981ccde07f: {'relation': 'present in work', 'head_span': {'text': 'Max', 'id': 'Q16422172'}, 'tail_span': {'text': 'second season', 'id': 'Q256235'}}
# 0cc5074dd25c18ee3fec65b04078cfb357800198: {'relation': 'cast member', 'head_span': {'text': 'Gaten Matarazzo', 'id': 'Q26704332'}, 'tail_span': {'text': 'Gabriella Pizzolo', 'id': 'Q26837233'}}
# 5daf1e465b5953d6811d23e0763d1e669e218951: {'relation': 'performer', 'head_span': {'text': 'Lucas Sinclair', 'id': 'Q56572628'}, 'tail_span': {'text': 'Caleb McLaughlin', 'id': 'Q26926382'}}
# 3a7072928ecabe26b50c68e6f6dc7fc856d9a033: {'relation': 'present in work', 'head_span': {'text': 'Eleven', 'id': 'Q37136'}, 'tail_span': {'text': 'Caleb McLaughlin', 'id': 'Q26926382'}}
# b509453ae308b3cea25304c7f0ebf4d13fa8850b: {'relation': 'characters', 'head_span': {'text': 'season two', 'id': 'Q114483519'}, 'tail_span': {'text': 'Eleven', 'id': 'Q37136'}}
# 8246406355e2762943f93ec987cc678d0f2d184d: {'relation': 'followed by', 'head_span': {'text': 'season two', 'id': 'Q114483519'}, 'tail_span': {'text': 'season three', 'id': 'Q114549977'}}
# b9ff4b36148c3da392f11a71fe83d92a7fae7572: {'relation': 'present in work', 'head_span': {'text': 'Eleven', 'id': 'Q37136'}, 'tail_span': {'text': 'season two', 'id': 'Q114483519'}}
# e33ca2b33a12e9c7f6c53013c0a08e325ae74ae6: {'relation': 'present in work', 'head_span': {'text': 'Eleven', 'id': 'Q37136'}, 'tail_span': {'text': 'season three', 'id': 'Q114549977'}}
# 032ef79e72dc0d3228dbb575390ce3fcff30b7e2: {'relation': 'follows', 'head_span': {'text': 'season three', 'id': 'Q114549977'}, 'tail_span': {'text': 'season two', 'id': 'Q114483519'}}
# 4219f1ef99657a972f3575da3e65ec0335fd58d8: {'relation': 'characters', 'head_span': {'text': 'season three', 'id': 'Q114549977'}, 'tail_span': {'text': 'Eleven', 'id': 'Q37136'}}
# fa36c215a3181d4098cab48bdb89ab13dc614b1a: {'relation': 'educated at', 'head_span': {'text': 'Caleb McLaughlin', 'id': 'Q26926382'}, 'tail_span': {'text': 'Hawkins High', 'id': 'id-less'}}
# 42a952d6951ba166ed1ad46f0a146fb20eac856f: {'relation': 'sibling', 'head_span': {'text': 'Mike', 'id': 'Q46384'}, 'tail_span': {'text': 'Holly', 'id': 'Q117085'}}
# 20b00aa007ae02e50b7dbff75c7573fe54b8852a: {'relation': 'sibling', 'head_span': {'text': 'Holly', 'id': 'Q117085'}, 'tail_span': {'text': 'Mike', 'id': 'Q46384'}}
# 47cb880fd26a9a172b94b5787b31613f335df30e: {'relation': 'sibling', 'head_span': {'text': 'Nancy Wheeler', 'id': 'Q65515695'}, 'tail_span': {'text': 'Mike', 'id': 'Q46384'}}
# c7de3aa6228c3bc510f616563ee31a71352e2406: {'relation': 'sibling', 'head_span': {'text': 'Nancy Wheeler', 'id': 'Q65515695'}, 'tail_span': {'text': 'Holly', 'id': 'Q117085'}}
# db4d9a567a758aecd5020fb686ae4526dfa1db17: {'relation': 'sibling', 'head_span': {'text': 'Nancy Wheeler', 'id': 'Q65515695'}, 'tail_span': {'text': 'Barbara', 'id': 'Q153957'}}
# 353f0af7c1ac9ae6535f428b44d8569bbbc3743a: {'relation': 'sibling', 'head_span': {'text': 'Mike', 'id': 'Q46384'}, 'tail_span': {'text': 'Nancy Wheeler', 'id': 'Q65515695'}}
# 81d29fdb2ada5b8b96649506dfddd34fd5508b11: {'relation': 'sibling', 'head_span': {'text': 'Holly', 'id': 'Q117085'}, 'tail_span': {'text': 'Nancy Wheeler', 'id': 'Q65515695'}}
# 4fc0ed6cf52f1a9cc88bd77a389a3bf1fc8d1111: {'relation': 'performer', 'head_span': {'text': 'Jonathan Byers', 'id': 'Q65515725'}, 'tail_span': {'text': 'Charlie Heaton', 'id': 'Q20974088'}}
# 37c19b59abb5aef2d40ae132efd8ec8151d9a812: {'relation': 'occupation', 'head_span': {'text': 'Jonathan Byers', 'id': 'Q65515725'}, 'tail_span': {'text': 'photographer', 'id': 'Q33231'}}
# a1c78906eeb29812455a615d65c443cd6c633b98: {'relation': 'spouse', 'head_span': {'text': 'Jonathan Byers', 'id': 'Q65515725'}, 'tail_span': {'text': 'Nancy Wheeler', 'id': 'Q65515695'}}
# 6a7ef63d1e13bf89d1d255563c235a5dc2713e0b: {'relation': 'spouse', 'head_span': {'text': 'Nancy Wheeler', 'id': 'Q65515695'}, 'tail_span': {'text': 'Jonathan Byers', 'id': 'Q65515725'}}
# ab85139b17aec055bb687a796e1174311047d478: {'relation': 'performer', 'head_span': {'text': 'Nancy', 'id': 'Q40898'}, 'tail_span': {'text': 'Cara Buono', 'id': 'Q289540'}}
# 57ac4f01d420ed51a6c990677cfc79e5e6ba11a8: {'relation': 'sibling', 'head_span': {'text': 'Nancy', 'id': 'Q40898'}, 'tail_span': {'text': 'Mike', 'id': 'Q46384'}}
# 871fffa21203c982b4a8a5cc86ae85b6c5dab805: {'relation': 'performer', 'head_span': {'text': 'Mike', 'id': 'Q46384'}, 'tail_span': {'text': 'Cara Buono', 'id': 'Q289540'}}
# a7df0c4979322a6abf0e5d2924ad10174b44f342: {'relation': 'sibling', 'head_span': {'text': 'Mike', 'id': 'Q46384'}, 'tail_span': {'text': 'Nancy', 'id': 'Q40898'}}
# 6bdcbf89902106ff0a5fcab1c9433be7975c7654: {'relation': 'performer', 'head_span': {'text': 'Holly', 'id': 'Q117085'}, 'tail_span': {'text': 'Cara Buono', 'id': 'Q289540'}}
# 60f093f8b4c3e9b14247970c64e3b86be28dd3d7: {'relation': 'child', 'head_span': {'text': 'Karen Wheeler', 'id': 'Q13560711'}, 'tail_span': {'text': 'Nancy', 'id': 'Q40898'}}
# 37feb4b3d6044fe2afd743338c181eb25a2f2a1b: {'relation': 'child', 'head_span': {'text': 'Karen Wheeler', 'id': 'Q13560711'}, 'tail_span': {'text': 'Mike', 'id': 'Q46384'}}
# 8606482b7360158a7f76e65236d75423f72aa791: {'relation': 'child', 'head_span': {'text': 'Karen Wheeler', 'id': 'Q13560711'}, 'tail_span': {'text': 'Holly', 'id': 'Q117085'}}
# 6303f0aa5797d1e6d318751a7a62a71d9ced2a17: {'relation': 'mother', 'head_span': {'text': 'Nancy', 'id': 'Q40898'}, 'tail_span': {'text': 'Karen Wheeler', 'id': 'Q13560711'}}
# d1c36d261354a9939f579e68dfb5b2d459a821aa: {'relation': 'mother', 'head_span': {'text': 'Mike', 'id': 'Q46384'}, 'tail_span': {'text': 'Karen Wheeler', 'id': 'Q13560711'}}
# cdea13d00a40754ff4a318acd4216f31cc018e12: {'relation': 'mother', 'head_span': {'text': 'Holly', 'id': 'Q117085'}, 'tail_span': {'text': 'Karen Wheeler', 'id': 'Q13560711'}}

# %%
params = [rel_dict for value, rel_dict in doc3._.rel.items()]
run_query(import_query, {'data': params})
# Out:
#   result
# 0   done

# %%
#Elena: el código de ladies no se ha ejecutado en este caso, pues no había indicación de si era necesario.

# %%
sparqlQuery = """
CALL apoc.periodic.iterate("
  MATCH (e:Entity)
  WHERE e.id STARTS WITH 'Q'
  RETURN e
","
  // Prepare a SparQL query
  WITH 'SELECT * WHERE{ ?item rdfs:label ?name . filter (?item = wd:' + e.id + ') filter (lang(?name) = \\\"en\\\") ' +
     'OPTIONAL {?item wdt:P31 [rdfs:label ?label] .filter(lang(?label)=\\\"en\\\")}}' AS sparql, e
  // make a request to Wikidata
  CALL apoc.load.jsonParams(
    'https://query.wikidata.org/sparql?query=' + 
      sparql,
      { Accept: 'application/sparql-results+json'}, null)
  YIELD value
  UNWIND value['results']['bindings'] as row
  SET e.wikipedia_name = row.name.value
  WITH e, row.label.value AS label
  MERGE (c:Class {id:label})
  MERGE (e)-[:INSTANCE_OF]->(c)
  RETURN distinct 'done'", {batchSize:1, retry:1})
"""
run_query(sparqlQuery)
# Out:
#    batches  total  timeTaken  committedOperations  failedOperations  \
# 0       26     26          2                    0                26
#
#    failedBatches  retries                                      errorMessages  \
# 0             26        0  {'Server returned HTTP response code: 400 for ...
#
#                                                batch  \
# 0  {'total': 26, 'committed': 0, 'failed': 26, 'e...
#
#                                           operations  wasTerminated  \
# 0  {'total': 26, 'committed': 0, 'failed': 26, 'e...          False
#
#   failedParams                                   updateStatistics
# 0           {}  {'nodesDeleted': 0, 'labelsAdded': 0, 'relatio...
